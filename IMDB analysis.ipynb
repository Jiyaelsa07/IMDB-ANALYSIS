# %%
from google.colab import files
files.upload()

# %%
import os
os.listdir()
# Out:
# ['.config', 'archive (1).zip', 'sample_data']

# %%
import zipfile

zip_ref = zipfile.ZipFile("archive (1).zip", 'r')
zip_ref.extractall()
zip_ref.close()

# %%
import pandas as pd

df = pd.read_csv("IMDB_Dataset_CLEANED.csv")
df.head()
# Out:
#                                               review sentiment
# 0  $25,000 Pyramid Clues: Deep Blue Sea. Tremors....  negative
# 1  0.5/10. This movie has absolutely nothing good...  negative
# 2  0*'s Christian Slater, Tara Reid, Stephen Dorf...  negative
# 3  102 Dalmatians (2000, Dir. Kevin Lima) <br /><...  negative
# 4  102 DALMATIANS [Walt Disney]: I wasn't a fan o...  negative

# %%
df.head()
# Out:
#                                               review sentiment
# 0  $25,000 Pyramid Clues: Deep Blue Sea. Tremors....  negative
# 1  0.5/10. This movie has absolutely nothing good...  negative
# 2  0*'s Christian Slater, Tara Reid, Stephen Dorf...  negative
# 3  102 Dalmatians (2000, Dir. Kevin Lima) <br /><...  negative
# 4  102 DALMATIANS [Walt Disney]: I wasn't a fan o...  negative

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 49396 entries, 0 to 49395
# Data columns (total 2 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   review     49396 non-null  object
#  1   sentiment  49396 non-null  object
# dtypes: object(2)
# memory usage: 771.9+ KB

# %%
df.isnull().sum()
# Out:
# review       0
# sentiment    0
# dtype: int64

# %%
df.dropna(inplace=True)

# %%
df['sentiment'].value_counts()
# Out:
# sentiment
# negative    24698
# positive    24698
# Name: count, dtype: int64

# %%
df['review_length'] = df['review'].apply(len)
df.head()
# Out:
#                                               review sentiment  review_length
# 0  $25,000 Pyramid Clues: Deep Blue Sea. Tremors....  negative           1147
# 1  0.5/10. This movie has absolutely nothing good...  negative            743
# 2  0*'s Christian Slater, Tara Reid, Stephen Dorf...  negative            844
# 3  102 Dalmatians (2000, Dir. Kevin Lima) <br /><...  negative            724
# 4  102 DALMATIANS [Walt Disney]: I wasn't a fan o...  negative            429

# %%
import matplotlib.pyplot as plt

df['sentiment'].value_counts().plot(kind='bar')
plt.title("Sentiment Count")
plt.xlabel("Sentiment")
plt.ylabel("Number of Reviews")
plt.show()

# %%
df['review_length'].mean()
# Out:
# np.float64(1310.5423313628635)
